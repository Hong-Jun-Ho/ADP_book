# %% [markdown]
# #### Part 04. 시각화
#
# <br>
#
# -----------------
#
# ## 1장. 산점도
#
# <p style='color:#726a77; text-align:right'>오민지 작성</p>
#
# ### 1절. 산점도
# - 두 개의 연속형 변수간의 관계를 알아볼 수 있도록 좌표평면 상에 관측점을 찍어 나타낸 그래프
# - 좌표형면 상의 관측점은 두 변수를 의미하는 x, y의 점으로 나타냄

# %% [markdown]
# 산점도 그리기 기본
# - plt.scatter(x, y, c, s, alpha)
#     - x, y : x축과 y축
#     - c: 색
#     - s: 마커의 면적
#     - alpha: 마커색의 투명도

# %% [markdown]
# __[예제]__
# cars93데이터의 length와 weight 변수에 대한 산점도 그리기

# %%
# 
import matplotlib.pyplot as plt
import pandas as pd

cars = pd.read_csv("Cars93.csv")

# %%
cars.columns
# Out:
# Index(['Manufacturer', 'Model', 'Type', 'Min.Price', 'Price', 'Max.Price',
#        'MPG.city', 'MPG.highway', 'AirBags', 'DriveTrain', 'Cylinders',
#        'EngineSize', 'Horsepower', 'RPM', 'Rev.per.mile', 'Man.trans.avail',
#        'Fuel.tank.capacity', 'Passengers', 'Length', 'Wheelbase', 'Width',
#        'Turn.circle', 'Rear.seat.room', 'Luggage.room', 'Weight', 'Origin',
#        'Make'],
#       dtype='object')

# %%
plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5)
plt.show()

# %% [markdown]
# ### 2절. 산점도 함수 옵션
# #### 1. 축이름, 그래프 제목
# - plt.xlabel('x축 이름')
# - plt.ylabel('y축 이름')
# - plt.title('그래프 제목', fontdict, loc, pad)
#     - fontdict 은 딕셔너리형태로 폰트에 대한 설정을 입력함
#         - fontsize 는 숫자단위를 입력하거나 'smaller', 'x-large' 등의 상대적인 설정 가능
#         - fontweight 는 'normal', 'bold', 'heavy', 'light', 'ultrabold', 'ultralight' 설정 가능
#     - loc는 위치. "left", "center", "right" 중 선택 가능
#     - pad는 타이틀과 그래프와의 간격(오프셋)을 포인트단위로 설정

# %% [markdown]
# __[예제]__
# Cars93의 Length와 Weight 변수에 대한 산점도에 제목과 축 이름을 지정하기

# %%
plt.title('Cars93', loc='right', pad=20)

title_font = {
    'fontsize':16,
    'fontweight': 'bold'
}

plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5)
plt.xlabel("Length")
plt.ylabel("Weight")
plt.title('Cars93', fontdict = title_font, loc='left', pad=20)
plt.show()

# %% [markdown]
# #### 2. 좌표축 범위
# - plt.axis([xmin, xmax, ymin, ymax])
# - 입력값이 없으면 데이터에 맞게 자동으로 범위를 지정해줌

# %% [markdown]
# __[예제]__
# Cars93의 Length와 Weight 변수에 대해 각각 최솟값, 최댓값을 구하고 적절한 축 범위를 지정하여 산점도 그리기

# %%
# length와 weight의 범위 구하기
a, b = cars['Length'].min(), cars['Length'].max()
print("Length의 최소값: %d, 최댓값: %d"%(a, b))
print('\n')
c, d = cars['Weight'].min(), cars['Weight'].max()
print("Weight의 최소값: %d, 최댓값: %d"%(c, d))
# Out:
# Length의 최소값: 141, 최댓값: 219
#
#
# Weight의 최소값: 1695, 최댓값: 4105

# %%
# x축과 y축 범위를 지정하여 산점도 그리기
# x축 범위 (130, 230), y 축 범위 (1600, 4400)으로 지정

plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5)
plt.axis([130, 230, 1600, 4400])

title_font = {
    'fontsize':20,
    'fontweight': 'bold'
}

plt.xlabel("Length")
plt.ylabel("Weight")
plt.title('Cars93', fontdict = title_font, loc='left', pad=20)
plt.show()

# %% [markdown]
# #### 3. 점의 종류
# ![python image](https://wikidocs.net/images/page/92083/set_marker_03.png)
#
# * 더 많은 마커종류는 https://matplotlib.org/3.1.1/api/markers_api.html ㄱㄱㄱ

# %%
plt.scatter(x=cars['Length'], y=cars['Weight'], marker='<')
plt.show()

# %% [markdown]
# #### 4. 점의 크기
# 산점도 그리기 기본에서 조정
# - plt.scatter(x, y, c, s, alpha)
#     - s: 마커의 면적

# %%
plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5, s=100)
plt.show()

# %% [markdown]
# #### 5. 색상
# 산점도 그리기 기본에서 조정
# - plt.scatter(x, y, c, s, alpha)
#     - c: 색

# %%
# 전체를 같은 색으로
plt.scatter(x=cars['Length'], y=cars['Weight'], alpha=0.5, s=100, c='green')
plt.show()

# %%
# 범주별로 색을 구분하기
groups = cars.groupby('AirBags')

fig, ax = plt.subplots()
for name, group in groups:
    ax.plot(group.Length,
           group.Weight,
            marker='o',
           linestyle='',
           label=name)
    
ax.legend(fontsize=9.5, loc='upper left')
plt.title('Scatter Plot by Groups', fontsize=20)
plt.xlabel('Length'); plt.ylabel('Weight')
plt.show()

# %%
# 범주별로 색과 스타일을 구분하기
import seaborn as sns

sns.scatterplot(x='Length',
               y='Weight',
               hue='AirBags',  #범주별로 색을 다르게지정하겠다는 뜻
               style='AirBags', #범주별로 스타일을 다르게 지정하겠다는 뜻
               s=50,
               data=cars)
plt.show()

# %% [markdown]
# #### 6. 그래프 종류 - 꺾은선 그래프

# %% [markdown]
# __[예제]__
# cars93 데이터에서 자동차의 무게(weight)별 평균길이(length)에 대한 산점도 그리기

# %%
### 자동차 무게 별 평균길이를 구하고 그래프를 그려보려 했으나...

cars_com = cars.dropna()
#avg = pd.Series(cars.groupby('Weight')['Length'].mean(), name='Length_avg')
avg = cars.pivot_table(values = 'Length', index = 'Weight', aggfunc = 'mean')
weight = cars['Weight'].sort_values().reset_index()
tb = pd.concat([weight, avg], axis=1)

# %%
# 왜 두 벡터(?)의 길이가 안 맞는지 모를............
print("weight의 길이: %d"%len(weight))
print("avg의 길이: %d"%len(avg))
# Out:
# weight의 길이: 93
# avg의 길이: 81

# %%
# 그래서.... R 코드 대신 올려드립니다......GG
"""
◇ type 인자에 "p"를 지정해서 점그래프를 만들기
plot(tapply(Cars93$Weight, Cars93$Length, mean), xlab='Length', ylab='Weight', type='p')

◇ type 인자에 'b'를 지정해서 꺾은선 그래프 만들기
plot(tapply(Cars93$Weight, Car93$Length, mean), xlab='Length', ylab='Weight', type='b')
"""

# %% [markdown]
# __[예제]__
# airquality 의 월별 평균 온도 한 눈에 알아볼 수 있도록 plot 함수 사용해 꺾은선 그래프로 시각화하기

# %%
"""
◇ 월별 평균온도에 대한 꺾은선 그래프
plot(tapply(airquality$Temp, airquality$Month, mean), type='b', ylim=c(60, 90),
    xlab='Month', ylab='Mean of Temperature', main='airquality')
    
↑ 인자 설명
◎ xlim=c(min, max) 와 ylim=c(min, max) : x축 및 y축의 최소최대 설정
◎ xlab 과 ylab : x축 및 y축의 레이블 설정
◎ main : 제목
"""

# %% [markdown]
# #### 7. 선 종류
#
# |문자 |설명|
# |------|---|
# |'-'|실선|
# |'--'|dash선|
# |'-.'|dash-dot선|
# |':'|점선|

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000)

plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted
